# %% [markdown]
# # Filtrando Top N Ações por Setor

# %%
import pandas as pd

# %%
df = pd.read_csv('../dataset/statusinvest-busca-avancada.csv', sep=';')

# %%
df
# Out:
#     TICKER  PRECO     DY        P/L   P/VP P/ATIVOS MARGEM BRUTA MARGEM EBIT  \
# 0    AALR3  21,19    NaN     -45,40   2,19     0,97        31,96        4,48
# 1    ABCB4  20,49   5,61       6,85   0,94     0,09        21,90       12,88
# 2    ABEV3  15,67   3,85      18,22   2,86     1,81        49,91       22,47
# 3    ADHM3   1,56    NaN      -4,09  -1,29   105,12       100,00  -13.548,48
# 4    AERI3   2,05   1,01  31.414,75   1,62     0,47        11,54        8,64
# ..     ...    ...    ...        ...    ...      ...          ...         ...
# 596  WHRL4   5,79  13,61      10,63   3,79     1,06        17,15        8,58
# 597  WIZS3   7,80   7,54       9,91   3,26     0,64        57,93       36,70
# 598  WLMM3  20,20   5,75       7,27   1,27     1,05        14,56        8,04
# 599  WLMM4  28,09   2,47      10,12   1,77     1,46        14,56        8,04
# 600  YDUQ3  14,20   0,89     405,04   1,40     0,44        54,39       12,04
#
# ...

# %%
df_ind = df[['TICKER', 'PRECO', 'P/L']]
df_ind
# Out:
#     TICKER  PRECO        P/L
# 0    AALR3  21,19     -45,40
# 1    ABCB4  20,49       6,85
# 2    ABEV3  15,67      18,22
# 3    ADHM3   1,56      -4,09
# 4    AERI3   2,05  31.414,75
# ..     ...    ...        ...
# 596  WHRL4   5,79      10,63
# 597  WIZS3   7,80       9,91
# 598  WLMM3  20,20       7,27
# 599  WLMM4  28,09      10,12
# 600  YDUQ3  14,20     405,04
#
# [601 rows x 3 columns]

# %% [markdown]
# ## 1. Calcular Endividamento

# %% [markdown]
# - Divida Liquida/Ebit -> Divida Atual
# - Passivo/Ativo -> Divida Futura
# - Liquidez Corrente -> Capacidade de Pagar as Dividas

# %% [markdown]
# ## 2. Calcular a Lucratividade

# %% [markdown]
# - Margem Bruta -> Receita Total
# - Margem Ebit -> Receita Descontando gastos
# - Margem Liquida -> Lucro que entra no Bolso

# %% [markdown]
# ## 3. Rentabilidade

# %% [markdown]
# - Roe -> Retorno sobre patrmonio liquido
# - Roic -> Retorno sobre patrimonio total da empresa

# %% [markdown]
# ## 4. Crescimento

# %% [markdown]
# - Cagr Lucros -> Quanto os lucros cresceram
# - Cagr Receita -> Quanto cresceu nos ultimos anos

# %% [markdown]
# ## 5. Valuation

# %% [markdown]
# - Formula Graham
# - Formula Fluxo de caixa descontado
